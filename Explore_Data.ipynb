# %% [markdown]
# # Intro

# %%
import requests
import pandas as pd
import datetime

# %%
# APIs needed for shared mobility services
# status of free floating systems
url_free_float = 'https://sharedmobility.ch/free_bike_status.json'

# status of renting stations
url_station_status = 'https://sharedmobility.ch/station_status.json'

# information on providers. Gives information of the type of vehicle that is rented out
# join with free_float and station_status on provider_id to determine the type of vehicle
url_provider = 'https://sharedmobility.ch/providers.json' 

# information on the stations. Gives information on the location
# join with station status on station_id to get location
url_station_information = 'https://sharedmobility.ch/station_information.json'

# weather API
key = 'TOKENXX' # API Key here
url_weather = f'https://api.openweathermap.org/data/2.5/weather?q=zurich&units=metric&appid={key}'

# %% [markdown]
# # Information on free floating systems

# %%
r = requests.get(url_free_float)

# When was it last updated
last_updated = r.json()['last_updated']
# Convert to datetime
dt = datetime.datetime.fromtimestamp(last_updated)

# Get the data on the vehicles
data = pd.DataFrame(r.json()['data']['bikes'])
# Add the timestamp as additional column
data['last_updated'] = dt
data
# Out:
#                                                  bike_id        lat       lon  \
# 0      voiscooters.com:56171c66-dba5-4a6d-bc81-c84020...  47.485950  8.766777
# 1      voiscooters.com:30a5d55e-580d-4fa1-ba02-2b5086...  47.502670  8.751773
# 2      voiscooters.com:c7cbe7a8-e4da-4c52-b0c9-fce235...  47.491550  8.706799
# 3      voiscooters.com:80fcb807-479a-4026-8cda-ce15b6...  47.506256  8.696448
# 4      voiscooters.com:f274025d-d138-4240-9f66-3d0d62...  47.506344  8.733712
# ...                                                  ...        ...       ...
# 12240                                      velospot:4111  46.175340  8.825917
# 12241                                      velospot:4115  46.172215  8.800830
# 12242                                      velospot:4116  46.155685  8.770183
# 12243                                      velospot:4120  46.154670  8.977515
# 12244                                      velospot:4124  47.570990  7.576283
#
#        is_disabled  is_reserved      provider_id rental_uris  \
# 0            False        False  voiscooters.com         NaN
# 1            False        False  voiscooters.com         NaN
# 2            False        False  voiscooters.com         NaN
# 3            False        False  voiscooters.com         NaN
# 4            False        False  voiscooters.com         NaN
# ...            ...          ...              ...         ...
# 12240        False        False         velospot          {}
# 12241        False        False         velospot          {}
# 12242        False        False         velospot          {}
# 12243        False        False         velospot          {}
# 12244        False        False         velospot          {}
#
#              last_updated
# 0     2023-10-07 10:07:13
# 1     2023-10-07 10:07:13
# 2     2023-10-07 10:07:13
# 3     2023-10-07 10:07:13
# 4     2023-10-07 10:07:13
# ...                   ...
# 12240 2023-10-07 10:07:13
# 12241 2023-10-07 10:07:13
# 12242 2023-10-07 10:07:13
# 12243 2023-10-07 10:07:13
# 12244 2023-10-07 10:07:13
#
# [12245 rows x 8 columns]

# %%
prop_unavailable = len(data[(data['is_reserved']|data['is_disabled'])])/len(data) # reserved or disabled
print(prop_unavailable)
prop_rented = len(data[data['is_disabled']])/(len(data)-len(data[data['is_reserved']])) # reserved vehicles of available not disabled vehicles
print(prop_rented)
# Out:
# 0.007676602694977542
# 0.006297023225384364

# %% [markdown]
# # Information on stations

# %%
r = requests.get(url_station_status)

# When was it last updated
last_updated = r.json()['last_updated']
# Convert to datetime
dt = datetime.datetime.fromtimestamp(last_updated)

# Get the data on the vehicles
data = pd.DataFrame(r.json()['data']['stations'])
data
# Out:
#            station_id  is_installed  is_renting  is_returning  last_reported  \
# 0     emobility:69636          True        True          True     1696661526
# 1     emobility:69644          True        True          True     1696661526
# 2     emobility:69652          True        True          True     1696661526
# 3     emobility:69677          True        True          True     1696661526
# 4     emobility:69682          True        True          True     1696661526
# ...               ...           ...         ...           ...            ...
# 6996      2em_cars:81          True        True          True     1696661405
# 6997    2em_cars:6076          True        True          True     1696661405
# 6998    2em_cars:7576          True        True          True     1696661405
# 6999    2em_cars:7577          True        True          True     1696661405
# 7000    2em_cars:7578          True        True          True     1696605903
#
#       num_bikes_available  num_docks_available provider_id
# 0                       0                  0.0   emobility
# 1                       3                  0.0   emobility
# 2                       1                  0.0   emobility
# 3                       2                  0.0   emobility
# 4                       1                  0.0   emobility
# ...                   ...                  ...         ...
# 6996                    1                  1.0    2em_cars
# 6997                    1                  1.0    2em_cars
# 6998                    1                  1.0    2em_cars
# 6999                    1                  1.0    2em_cars
# 7000                    1                  1.0    2em_cars
#
# [7001 rows x 8 columns]

# %% [markdown]
# # Information on providers

# %%
r = requests.get(url_provider)

# When was it last updated
last_updated = r.json()['last_updated']
# Convert to datetime
dt = datetime.datetime.fromtimestamp(last_updated)

# Get the data on the vehicles
data = pd.DataFrame(r.json()['data']['providers'])
data
# Out:
#                               provider_id  ttl language  \
# 0                               publibike  180       en
# 1                              carvelo2go   60       en
# 2                         voiscooters.com    0       en
# 3                              publiebike  180       en
# 4                        edrivecarsharing   60       en
# 5                                mobility  300       en
# 6                               emobility  300       en
# 7                                    tier   60       en
# 8                               sponticar   60       en
# 9                             nextbike_ch   60       en
# 10                            donkey_thun   60       en
# 11                       donkey_neuchatel   60       en
# 12               donkey_yverdon-les-bains   60       en
# 13                            donkey_sion   60       en
# 14                        donkey_le_locle   60       en
# 15                              donkey_ge   60       en
# 16   bird-platform-partner-jmfleets-bulle   60       en
# 17  bird-platform-partner-jmfleetswl-biel   60       en
# 18                             tier_ebike   60       en
# 19                               2em_cars  300       en
# 20                      lime_zurich_ebike    0       en
# 21                   lime_zurich_escooter    0       en
# 22                  lime_opfikon_escooter    0       en
# 23                      lime_zug_escooter    0       en
# 24                    lime_uster_escooter    0       en
# 25               lime_winterthur_escooter    0       en
# 26                    lime_basel_escooter    0       en
# 27                     lime_opfikon_ebike    0       en
# 28                 lime_wetzikon_escooter    0       en
# 29                  pickebike_basel_ebike   60       en
# 30                 pickebike_basel_emoped   60       en
# 31               pickebike_fribourg_ebike   60       en
# 32                pickebike_aubonne_ebike   60       en
# 33                   bird-zurich-escooter   60       en
# 34                    bird-basel-escooter   60       en
# 35                   bird-kloten-escooter   60       en
# 36           liemobil_liechtenstein_ebike   60       en
# 37                        share_birrer_ch  300       en
# 38                     donkey_kreuzlingen   60       en
# 39                        bird-winterthur   60       en
# 40                               velospot   60       en
#
#                       name vehicle_type         timezone  \
# 0                Publibike         Bike              MEZ
# 1               Carvelo2go  E-CargoBike    Europe/Zurich
# 2                      Voi    E-Scooter              UTC
# 3                PubliBike       E-Bike              MEZ
# 4        edrive carsharing        E-Car    Europe/Zurich
# 5                 Mobility          Car              CET
# 6                 Mobility        E-Car              CET
# 7   TIER E-Scooter-Sharing    E-Scooter              CET
# 8               Sponti-Car        E-Car              CET
# 9                 Nextbike         Bike  Europe/Brussels
# 10         Donkey Republik         Bike    Europe/Zurich
# 11         Donkey Republic         Bike    Europe/Zurich
# 12         Donkey Republic         Bike    Europe/Zurich
# 13         Donkey Republic         Bike    Europe/Zurich
# 14         Donkey Republic         Bike    Europe/Zurich
# 15         Donkey Republic         Bike    Europe/Zurich
# 16               JM Fleets    E-Scooter    Europe/Zurich
# 17               JM Fleets    E-Scooter    Europe/Zurich
# 18     TIER E-Bike-Sharing       E-Bike              CET
# 19         2EM Car Sharing          Car    Europe/Zurich
# 20                    Lime       E-Bike    Europe/Zurich
# 21                    Lime    E-Scooter    Europe/Zurich
# 22                    Lime    E-Scooter    Europe/Zurich
# 23                    Lime    E-Scooter    Europe/Zurich
# 24                    Lime    E-Scooter    Europe/Zurich
# 25                    Lime    E-Scooter    Europe/Zurich
# 26                    Lime    E-Scooter    Europe/Zurich
# 27                    Lime       E-Bike    Europe/Zurich
# 28                    Lime    E-Scooter    Europe/Zurich
# 29       Pick-e-Bike Basel       E-Bike    Europe/Zurich
# 30       Pick-e-Bike Basel      E-Moped    Europe/Zurich
# 31    Pick-e-Bike Fribourg       E-Bike    Europe/Zurich
# 32     Pick-e-Bike Aubonne       E-Bike    Europe/Zurich
# 33                    Bird    E-Scooter    Europe/Zurich
# 34                    Bird    E-Scooter    Europe/Zurich
# 35                    Bird    E-Scooter    Europe/Zurich
# 36                LIEmobil       E-Bike    Europe/Zurich
# 37         Share Birrer AG        E-Car    Europe/Zurich
# 38             Regivelo.ch         Bike    Europe/Zurich
# 39                    Bird    E-Scooter    Europe/Zurich
# 40                Velospot         Bike    Europe/Zurich
#
#                                           rental_apps  last_updated  \
# 0   {'ios': {'store_uri': 'https://apps.apple.com/...    1696661576
# 1   {'ios': {'store_uri': 'https://apps.apple.com/...    1696661678
# 2   {'ios': {'store_uri': 'https://apps.apple.com/...    1696661700
# 3   {'ios': {'store_uri': 'https://apps.apple.com/...    1696661675
# 4   {'ios': {'store_uri': 'https://apps.apple.com/...    1696661676
# 5   {'ios': {'store_uri': 'https://apps.apple.com/...    1696661529
# 6   {'ios': {'store_uri': 'https://apps.apple.com/...    1696661526
# 7   {'ios': {'store_uri': 'https://apps.apple.com/...    1696661650
# 8                                                 NaN    1696661699
# 9   {'ios': {'store_uri': 'https://apps.apple.com/...    1696661594
# 10  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661661
# 11  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661661
# 12  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661661
# 13  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661599
# 14  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661660
# 15  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661662
# 16  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661676
# 17  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661652
# 18  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661674
# 19  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661405
# 20  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661680
# 21  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661680
# 22  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661625
# 23  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661589
# 24  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661635
# 25  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661661
# 26  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661680
# 27  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661688
# 28  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661634
# 29  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661580
# 30  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661640
# 31  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661641
# 32  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661580
# 33  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661625
# 34  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661681
# 35  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661626
# 36  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661580
# 37  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661403
# 38  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661669
# 39  {'ios': {'store_uri': 'https://apps.apple.com/...    1696661648
# 40                                                NaN    1696658100
#
#                                              operator  \
# 0                                                 NaN
# 1                       Mobilitätsakademie AG des TCS
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   TIER Mobility SE - Erich-Zeigner Allee 69-73 -...
# 10                                    Donkey Republic
# 11                                    Donkey Republic
# 12                                    Donkey Republic
# 13                                    Donkey Republic
# 14                                    Donkey Republic
# 15                                    Donkey Republic
# 16                                   Bird Rides, Inc.
# 17                                   Bird Rides, Inc.
# 18                                                NaN
# 19                                    2EM Car Sharing
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                   Bird Rides, Inc.
# 34                                   Bird Rides, Inc.
# 35                                   Bird Rides, Inc.
# 36                                                NaN
# 37                                                NaN
# 38                                    Donkey Republic
# 39                                   Bird Rides, Inc.
# 40                                                NaN
#
#                                                   url  \
# 0                                                 NaN
# 1                              https://www.carvelo.ch
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                             https://www.mobility.ch
# 6                             https://www.mobility.ch
# 7                                                 NaN
# 8                              https://sponti-car.ch/
# 9                         https://www.nextbike.de/de/
# 10   https://www.donkey.bike/cities/bike-rental-thun/
# 11  https://www.donkey.bike/cities/bike-rental-neu...
# 12  https://www.donkey.bike/cities/bike-rental-yve...
# 13   https://www.donkey.bike/cities/bike-rental-sion/
# 14  https://www.donkey.bike/cities/bike-rental-le-...
# 15  https://www.donkey.bike/cities/bike-rental-gen...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                 https://www.2em.ch
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38  https://www.donkey.bike/cities/bike-rental-kre...
# 39                                                NaN
# 40              https://velospot.info/customer/public
#
#                          email       phone_number  \
# 0                          NaN                NaN
# 1              info@carvelo.ch      058 827 34 14
# 2                          NaN                NaN
# 3                          NaN                NaN
# 4                          NaN                NaN
# 5           office@mobility.ch                NaN
# 6           office@mobility.ch                NaN
# 7                          NaN                NaN
# 8           info@sponti-car.ch      055 264 10 00
# 9             info@nextbike.ch      0041415080800
# 10  support@donkeyrepublic.com  0041 31 539 18 90
# 11  support@donkeyrepublic.com  0041 31 539 18 90
# 12  support@donkeyrepublic.com  0041 31 539 18 90
# 13  support@donkeyrepublic.com  0041 31 539 18 90
# 14  support@donkeyrepublic.com  0041 31 539 18 90
# 15  support@donkeyrepublic.com       +41315391890
# 16                         NaN                NaN
# 17                         NaN                NaN
# 18                         NaN                NaN
# 19              contact@2em.ch  0041 58 255 28 66
# 20                         NaN                NaN
# 21                         NaN                NaN
# 22                         NaN                NaN
# 23                         NaN                NaN
# 24                         NaN                NaN
# 25                         NaN                NaN
# 26                         NaN                NaN
# 27                         NaN                NaN
# 28                         NaN                NaN
# 29                         NaN       +41848020304
# 30                         NaN       +41848020304
# 31                         NaN       +41848020304
# 32                         NaN       +41218215400
# 33                         NaN                NaN
# 34                         NaN                NaN
# 35                         NaN                NaN
# 36                         NaN        +4232379494
# 37                         NaN                NaN
# 38  support@donkeyrepublic.com  0041 31 539 18 90
# 39                         NaN                NaN
# 40            info@velospot.ch                NaN
#
#                         purchase_url
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 6                                NaN
# 7                                NaN
# 8           https://ibiola.com/login
# 9                                NaN
# 10  https://www.donkey.bike/pricing/
# 11  https://www.donkey.bike/pricing/
# 12  https://www.donkey.bike/pricing/
# 13  https://www.donkey.bike/pricing/
# 14  https://www.donkey.bike/pricing/
# 15  https://www.donkey.bike/pricing/
# 16                               NaN
# 17                               NaN
# 18                               NaN
# 19                https://www.2em.ch
# 20                               NaN
# 21                               NaN
# 22                               NaN
# 23                               NaN
# 24                               NaN
# 25                               NaN
# 26                               NaN
# 27                               NaN
# 28                               NaN
# 29                               NaN
# 30                               NaN
# 31                               NaN
# 32                               NaN
# 33                               NaN
# 34                               NaN
# 35                               NaN
# 36                               NaN
# 37                               NaN
# 38  https://www.donkey.bike/pricing/
# 39                               NaN
# 40                               NaN

# %% [markdown]
# # Information on stations

# %%
r = requests.get(url_station_information)

# When was it last updated
last_updated = r.json()['last_updated']
# Convert to datetime
dt = datetime.datetime.fromtimestamp(last_updated)

# Get the data on the vehicles
data = pd.DataFrame(r.json()['data']['stations'])
data
# Out:
#                 station_id                                name        lat  \
# 0     edrivecarsharing:566       edrive Renault Zoe TG 197 872  47.514965
# 1     edrivecarsharing:638       edrive Renault Zoe TG 197 606  47.515022
# 2     edrivecarsharing:776              Martishöhe Renault Zoé  47.130290
# 3     edrivecarsharing:808              LANDI Thun Renault Zoe  46.772510
# 4     edrivecarsharing:839              LANDI Thun Renault Zoe  46.814310
# ...                    ...                                 ...        ...
# 7053           2em_cars:81   Opel Zafira 1.4i Turbo Cosmo 2012  46.779694
# 7054         2em_cars:6076                         Bmw X3 2013  47.457870
# 7055         2em_cars:7576                    Toyota Aygo 2006  47.127460
# 7056         2em_cars:7577  Volkswagen Golf 2.0 TDI Style 2020  46.431220
# 7057         2em_cars:7578  Volkswagen Golf 2.0 TDI Style 2020  46.431220
#
#            lon       provider_id address region_id post_code  \
# 0     8.936660  edrivecarsharing     NaN       NaN       NaN
# 1     8.936639  edrivecarsharing     NaN       NaN       NaN
# 2     8.197523  edrivecarsharing     NaN       NaN       NaN
# 3     7.630810  edrivecarsharing     NaN       NaN       NaN
# 4     7.511653  edrivecarsharing     NaN       NaN       NaN
# ...        ...               ...     ...       ...       ...
# 7053  7.156063          2em_cars     NaN       NaN       NaN
# 7054  8.634514          2em_cars     NaN       NaN       NaN
# 7055  7.260122          2em_cars     NaN       NaN       NaN
# 7056  6.910680          2em_cars     NaN       NaN       NaN
# 7057  6.910680          2em_cars     NaN       NaN       NaN
#
#                                             rental_uris short_name
# 0                                                   NaN        NaN
# 1                                                   NaN        NaN
# 2                                                   NaN        NaN
# 3                                                   NaN        NaN
# 4                                                   NaN        NaN
# ...                                                 ...        ...
# 7053  {'web': 'https://www.2em.ch/location-voiture/m...        NaN
# 7054  {'web': 'https://www.2em.ch/location-voiture/u...        NaN
# 7055  {'web': 'https://www.2em.ch/location-voiture/b...        NaN
# 7056  {'web': 'https://www.2em.ch/location-voiture/m...        NaN
# 7057  {'web': 'https://www.2em.ch/location-voiture/m...        NaN
#
# [7058 rows x 10 columns]

# %% [markdown]
# # Weather API

# %%
r = requests.get(url_weather)
# what metrics do we want to track?
print(r.json())

# info on weather conditions: https://openweathermap.org/weather-conditions
# note: create a table in database for weather conditions
weather = r.json()['weather']
print(weather)

# timestamp
last_updated = r.json()['dt']
# Convert to datetime
dt = datetime.datetime.fromtimestamp(last_updated)
print(dt)

# temperature, pressure, humidity
temperature = r.json()['main']
print(temperature)
# Out:
# {'coord': {'lon': 8.55, 'lat': 47.3667}, 'weather': [{'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 12.72, 'feels_like': 12.5, 'temp_min': 9.09, 'temp_max': 16.85, 'pressure': 1028, 'humidity': 94}, 'visibility': 200, 'wind': {'speed': 2.06, 'deg': 110}, 'clouds': {'all': 40}, 'dt': 1696665284, 'sys': {'type': 2, 'id': 2019255, 'country': 'CH', 'sunrise': 1696656727, 'sunset': 1696697708}, 'timezone': 7200, 'id': 2657896, 'name': 'Zurich', 'cod': 200}
# [{'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50d'}]
# 2023-10-07 09:54:44
# {'temp': 12.72, 'feels_like': 12.5, 'temp_min': 9.09, 'temp_max': 16.85, 'pressure': 1028, 'humidity': 94}
