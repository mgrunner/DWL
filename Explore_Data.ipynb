# %%
import requests
import pandas as pd

url = 'https://api.sharedmobility.ch/v1/sharedmobility/find?filters=ch.bfe.sharedmobility.pickup_type=free_floating'
r = requests.get(url)
r.json()
# Out:
# [{'geometry': {'x': 8.686035,
#    'y': 47.42497,
#    'spatialReference': {'wkid': 4326}},
#   'attributes': {'provider.id': 'voiscooters.com',
#    'provider.name': 'Voi',
#    'provider.timezone': 'UTC',
#    'provider.apps.ios.store_uri': 'https://apps.apple.com/ch/app/voi-scooters-get-magic-wheels/id1395921017',
#    'provider.apps.android.store_uri': 'https://play.google.com/store/apps/details?id=io.voiapp.voi',
#    'id': 'voiscooters.com:2d90b18a-d009-45c3-ae31-dc434700a84a',
#    'available': True,
#    'pickup_type': 'free_floating',
#    'vehicle_type': 'E-Scooter',
#    'vehicle.status.disabled': False,
#    'vehicle.status.reserved': False},
#   'featureId': 'voiscooters.com:2d90b18a-d009-45c3-ae31-dc434700a84a',
#   'id': 'voiscooters.com:2d90b18a-d009-45c3-ae31-dc434700a84a',
#   'layerBodId': 'ch.bfe.sharedmobility',
#   'layerName': 'Shared Mobility Angebote'},
#  {'geometry': {'x': 8.476813,
#    'y': 47.39132,
#    'spatialReference': {'wkid': 4326}},
# ...

# %%
r
# Out:
# <Response [200]>
